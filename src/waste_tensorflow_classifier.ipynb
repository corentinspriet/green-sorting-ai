# %%
import json
import pandas as pd
import numpy as np

data_path = "../data/dechets.json"

with open(data_path, "r", encoding="utf-8") as f:
    raw_data = json.load(f)

df = pd.DataFrame(raw_data)
df.head()
# Out:
#                 description           label
# 0          emballage papier          papier
# 1         enveloppe blanche          papier
# 2  litière de chat souillée  non-recyclable
# 3            peau de banane       organique
# 4          ampoule halogène  non-recyclable

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split


texts = df["description"].values
labels = df["label"].values

def nettoyer_texte(texte):
    import unicodedata
    texte = texte.lower()
    texte = ''.join(
        c for c in unicodedata.normalize('NFD', texte)
        if unicodedata.category(c) != 'Mn'  # supprime les accents
    )
    return texte

def regrouper_classes(label):
    if label in ["papier", "carton"]:
        return "papier_carton"
    elif label in ["textile", "électronique"]:
        return "autres"
    else:
        return label

# Nettoyage et regroupement
df["description"] = df["description"].apply(nettoyer_texte)
df["label"] = df["label"].apply(regrouper_classes)

label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)


X_train, X_test, y_train, y_test = train_test_split(
    texts, encoded_labels, test_size=0.2, random_state=42, stratify=encoded_labels
)


print(f"Exemple : '{X_train[0]}' → {y_train[0]} ({label_encoder.inverse_transform([y_train[0]])[0]})")
print(f"\nNombre de classes : {len(label_encoder.classes_)} → {label_encoder.classes_}")
# Out:
# Exemple : 'papier aluminium usage' → 2 (métal)
#
# Nombre de classes : 8 → ['autres' 'compost' 'métal' 'non-recyclable' 'organique' 'papier_carton'
#  'plastique' 'verre']

# %%
import tensorflow as tf
from tensorflow.keras.layers import TextVectorization, Embedding, GlobalAveragePooling1D, Dense
from tensorflow.keras.models import Sequential

# ⚙️ Paramètres
max_tokens = 5000   # taille du vocabulaire
output_dim = 64     # dimension des embeddings
sequence_length = 50  # nombre max de mots par texte
num_classes = len(label_encoder.classes_)

# 🔠 Text vectorizer
vectorizer = TextVectorization(max_tokens=max_tokens, output_sequence_length=sequence_length)
vectorizer.adapt(X_train)

# ✅ Modèle simple
model = Sequential([
    vectorizer,
    Embedding(input_dim=max_tokens, output_dim=output_dim),
    GlobalAveragePooling1D(),
    Dense(64, activation="relu"),
    Dense(num_classes, activation="softmax")
])

# ⚙️ Compilation
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

# 👀 Aperçu
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  text_vectorization_4 (Text  (None, 50)                0
#  Vectorization)
#
#  embedding_4 (Embedding)     (None, 50, 64)            320000
#
#  global_average_pooling1d_4  (None, 64)                0
#   (GlobalAveragePooling1D)
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  dense_9 (Dense)             (None, 8)                 520
#
# =================================================================
# Total params: 324680 (1.24 MB)
# Trainable params: 324680 (1.24 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Entraînement
history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 1s 106ms/step - loss: 2.0761 - accuracy: 0.2500 - val_loss: 2.0778 - val_accuracy: 0.1364
# Epoch 2/50
# 3/3 [==============================] - 0s 23ms/step - loss: 2.0685 - accuracy: 0.2500 - val_loss: 2.0748 - val_accuracy: 0.1364
# Epoch 3/50
# 3/3 [==============================] - 0s 23ms/step - loss: 2.0586 - accuracy: 0.2500 - val_loss: 2.0730 - val_accuracy: 0.1364
# Epoch 4/50
# 3/3 [==============================] - 0s 27ms/step - loss: 2.0503 - accuracy: 0.2500 - val_loss: 2.0708 - val_accuracy: 0.1364
# Epoch 5/50
# 3/3 [==============================] - 0s 24ms/step - loss: 2.0433 - accuracy: 0.2500 - val_loss: 2.0690 - val_accuracy: 0.1364
# Epoch 6/50
# 3/3 [==============================] - 0s 24ms/step - loss: 2.0351 - accuracy: 0.2500 - val_loss: 2.0678 - val_accuracy: 0.1364
# Epoch 7/50
# 3/3 [==============================] - 0s 23ms/step - loss: 2.0259 - accuracy: 0.2500 - val_loss: 2.0669 - val_accuracy: 0.1364
# Epoch 8/50
# 3/3 [==============================] - 0s 23ms/step - loss: 2.0173 - accuracy: 0.2500 - val_loss: 2.0668 - val_accuracy: 0.1364
# Epoch 9/50
# 3/3 [==============================] - 0s 28ms/step - loss: 2.0087 - accuracy: 0.2500 - val_loss: 2.0681 - val_accuracy: 0.1364
# Epoch 10/50
# 3/3 [==============================] - 0s 25ms/step - loss: 1.9999 - accuracy: 0.2500 - val_loss: 2.0700 - val_accuracy: 0.1364
# Epoch 11/50
# 3/3 [==============================] - 0s 26ms/step - loss: 1.9912 - accuracy: 0.2500 - val_loss: 2.0727 - val_accuracy: 0.1364
# Epoch 12/50
# 3/3 [==============================] - 0s 24ms/step - loss: 1.9819 - accuracy: 0.2500 - val_loss: 2.0761 - val_accuracy: 0.1364
# Epoch 13/50
# 3/3 [==============================] - 0s 21ms/step - loss: 1.9748 - accuracy: 0.2500 - val_loss: 2.0804 - val_accuracy: 0.1364
# Epoch 14/50
# 3/3 [==============================] - 0s 23ms/step - loss: 1.9682 - accuracy: 0.2500 - val_loss: 2.0864 - val_accuracy: 0.1364
# Epoch 15/50
# 3/3 [==============================] - 0s 25ms/step - loss: 1.9607 - accuracy: 0.2500 - val_loss: 2.0931 - val_accuracy: 0.1364
# Epoch 16/50
# 3/3 [==============================] - 0s 25ms/step - loss: 1.9546 - accuracy: 0.2500 - val_loss: 2.1014 - val_accuracy: 0.1364
# Epoch 17/50
# 3/3 [==============================] - 0s 23ms/step - loss: 1.9495 - accuracy: 0.2500 - val_loss: 2.1099 - val_accuracy: 0.1364
# Epoch 18/50
# 3/3 [==============================] - 0s 20ms/step - loss: 1.9448 - accuracy: 0.2500 - val_loss: 2.1187 - val_accuracy: 0.1364
# Epoch 19/50
# 3/3 [==============================] - 0s 22ms/step - loss: 1.9403 - accuracy: 0.2500 - val_loss: 2.1264 - val_accuracy: 0.1364
# Epoch 20/50
# 3/3 [==============================] - 0s 32ms/step - loss: 1.9388 - accuracy: 0.2500 - val_loss: 2.1356 - val_accuracy: 0.1364
# Epoch 21/50
# 3/3 [==============================] - 0s 23ms/step - loss: 1.9355 - accuracy: 0.2500 - val_loss: 2.1433 - val_accuracy: 0.1364
# Epoch 22/50
# 3/3 [==============================] - 0s 25ms/step - loss: 1.9330 - accuracy: 0.2500 - val_loss: 2.1490 - val_accuracy: 0.1364
# Epoch 23/50
# 3/3 [==============================] - 0s 21ms/step - loss: 1.9313 - accuracy: 0.2500 - val_loss: 2.1541 - val_accuracy: 0.1364
# Epoch 24/50
# 3/3 [==============================] - 0s 21ms/step - loss: 1.9300 - accuracy: 0.2500 - val_loss: 2.1595 - val_accuracy: 0.1364
# Epoch 25/50
# 3/3 [==============================] - 0s 21ms/step - loss: 1.9272 - accuracy: 0.2500 - val_loss: 2.1613 - val_accuracy: 0.1364
# Epoch 26/50
# 3/3 [==============================] - 0s 22ms/step - loss: 1.9259 - accuracy: 0.2500 - val_loss: 2.1618 - val_accuracy: 0.1364
# Epoch 27/50
# 3/3 [==============================] - 0s 21ms/step - loss: 1.9237 - accuracy: 0.2500 - val_loss: 2.1631 - val_accuracy: 0.1364
# Epoch 28/50
# 3/3 [==============================] - 0s 23ms/step - loss: 1.9222 - accuracy: 0.2500 - val_loss: 2.1648 - val_accuracy: 0.1364
# Epoch 29/50
# 3/3 [==============================] - 0s 23ms/step - loss: 1.9199 - accuracy: 0.2500 - val_loss: 2.1658 - val_accuracy: 0.1364
# Epoch 30/50
# 3/3 [==============================] - 0s 24ms/step - loss: 1.9185 - accuracy: 0.2500 - val_loss: 2.1679 - val_accuracy: 0.1364
# Epoch 31/50
# 3/3 [==============================] - 0s 26ms/step - loss: 1.9166 - accuracy: 0.2500 - val_loss: 2.1690 - val_accuracy: 0.1364
# Epoch 32/50
# 3/3 [==============================] - 0s 26ms/step - loss: 1.9150 - accuracy: 0.2500 - val_loss: 2.1660 - val_accuracy: 0.1364
# Epoch 33/50
# 3/3 [==============================] - 0s 25ms/step - loss: 1.9128 - accuracy: 0.2500 - val_loss: 2.1655 - val_accuracy: 0.1364
# Epoch 34/50
# 3/3 [==============================] - 0s 22ms/step - loss: 1.9107 - accuracy: 0.2500 - val_loss: 2.1651 - val_accuracy: 0.1364
# Epoch 35/50
# 3/3 [==============================] - 0s 21ms/step - loss: 1.9087 - accuracy: 0.2500 - val_loss: 2.1641 - val_accuracy: 0.1364
# Epoch 36/50
# 3/3 [==============================] - 0s 22ms/step - loss: 1.9067 - accuracy: 0.2500 - val_loss: 2.1624 - val_accuracy: 0.1364
# Epoch 37/50
# 3/3 [==============================] - 0s 23ms/step - loss: 1.9042 - accuracy: 0.2500 - val_loss: 2.1616 - val_accuracy: 0.1364
# Epoch 38/50
# 3/3 [==============================] - 0s 23ms/step - loss: 1.9021 - accuracy: 0.2500 - val_loss: 2.1627 - val_accuracy: 0.1364
# Epoch 39/50
# 3/3 [==============================] - 0s 23ms/step - loss: 1.8995 - accuracy: 0.2500 - val_loss: 2.1631 - val_accuracy: 0.1364
# Epoch 40/50
# 3/3 [==============================] - 0s 26ms/step - loss: 1.8969 - accuracy: 0.2500 - val_loss: 2.1635 - val_accuracy: 0.1364
# Epoch 41/50
# 3/3 [==============================] - 0s 24ms/step - loss: 1.8941 - accuracy: 0.2500 - val_loss: 2.1625 - val_accuracy: 0.1364
# Epoch 42/50
# 3/3 [==============================] - 0s 24ms/step - loss: 1.8924 - accuracy: 0.2500 - val_loss: 2.1610 - val_accuracy: 0.1364
# Epoch 43/50
# 3/3 [==============================] - 0s 22ms/step - loss: 1.8887 - accuracy: 0.2500 - val_loss: 2.1621 - val_accuracy: 0.1364
# Epoch 44/50
# 3/3 [==============================] - 0s 23ms/step - loss: 1.8863 - accuracy: 0.2500 - val_loss: 2.1644 - val_accuracy: 0.1364
# Epoch 45/50
# 3/3 [==============================] - 0s 23ms/step - loss: 1.8825 - accuracy: 0.2500 - val_loss: 2.1627 - val_accuracy: 0.1364
# Epoch 46/50
# 3/3 [==============================] - 0s 23ms/step - loss: 1.8794 - accuracy: 0.2500 - val_loss: 2.1609 - val_accuracy: 0.1364
# Epoch 47/50
# 3/3 [==============================] - 0s 23ms/step - loss: 1.8758 - accuracy: 0.2500 - val_loss: 2.1605 - val_accuracy: 0.1364
# Epoch 48/50
# 3/3 [==============================] - 0s 26ms/step - loss: 1.8723 - accuracy: 0.2500 - val_loss: 2.1605 - val_accuracy: 0.1364
# Epoch 49/50
# 3/3 [==============================] - 0s 24ms/step - loss: 1.8686 - accuracy: 0.2500 - val_loss: 2.1602 - val_accuracy: 0.1364
# Epoch 50/50
# 3/3 [==============================] - 0s 21ms/step - loss: 1.8647 - accuracy: 0.2500 - val_loss: 2.1564 - val_accuracy: 0.1364

# %%
# Évaluation sur test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f"\nTest accuracy: {accuracy:.2f}")

# Exemple de prédiction
sample_texts = [
    "bouteille en plastique transparente",
    "journal froissé",
    "reste de nourriture organique"
]

pred_probs = model.predict(sample_texts)
pred_labels = np.argmax(pred_probs, axis=1)
pred_classes = label_encoder.inverse_transform(pred_labels)

for text, label in zip(sample_texts, pred_classes):
    print(f"Texte : '{text}' → Prédit : {label}")
# Out:
# 1/1 [==============================] - 0s 32ms/step - loss: 1.9274 - accuracy: 0.2500
#
# Test accuracy: 0.25
# 1/1 [==============================] - 0s 109ms/step
# Texte : 'bouteille en plastique transparente' → Prédit : papier_carton
# Texte : 'journal froissé' → Prédit : papier_carton
# Texte : 'reste de nourriture organique' → Prédit : papier_carton
